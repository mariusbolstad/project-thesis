# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
from models.arima_forecasts import ARIMA_forecast, find_arima_spec
from models.random_walk import random_walk_forecast
from models.ann import ANN_forecast
from helper_functions import compute_rmse, load_monthly_baci_data, load_daily_baci_data, load_weekly_baci_data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from statsmodels.tools.sm_exceptions import ValueWarning


# Suppress all warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=ValueWarning)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <frozen importlib._bootstrap_external>:1437, in _path_importer_cache(cls, path)
#
# KeyError: 'C:\\Users\\mariumbo\\AppData\\Roaming\\Python\\Python311\\site-packages\\tensorflow\\_api\\v2\\compat\\v1\\dtypes'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\mariumbo\project-thesis\exog_forecasts.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mariumbo/project-thesis/exog_forecasts.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from keras.models import Sequential
#       <a href='vscode-notebook-cell:/c%3A/Users/mariumbo/project-thesis/exog_forecasts.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> from keras.layers import Dense
# ...

# %%
import pandas as pd

# 1. Load the CSV files into pandas dataframes
df_baci = pd.read_csv('./data/all_baci.csv', parse_dates=['Date'], index_col='Date')
df_iron_fut = pd.read_csv('./data/iron_ore_futures_daily.csv', parse_dates=['Date'], index_col='Date')

# Inner join both dataframes on their index to ensure they have the same timestamp
result = df_baci.join(df_iron_fut, how='inner', lsuffix='_baci', rsuffix='_ironfut')

# Split the result back into individual dataframes if needed
df_baci_filtered = result[['CLOSE_baci']]
df_iron_fut_filtered = result[['CLOSE_ironfut']]

print(df_baci_filtered.head())
print(df_iron_fut_filtered.head())

# %%
train = data["CLOSE"].iloc[:train_size]
test = data["CLOSE"].iloc[train_size:train_size + months_ahead]

ann_fitted_df, ann_forecast_df = ANN_diff_forecast(train=train, 
                                                      test=test, 
                                                      steps_ahead=months_ahead,
                                                      lookback=ann_spec[0],
                                                      hidden_units=ann_spec[1])
